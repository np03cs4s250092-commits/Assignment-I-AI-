# %% [markdown]
# <a href="https://colab.research.google.com/github/np03cs4s250092-commits/Assignment-I-AI-/blob/main/2548321_Rejina_Rana_Magar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/content/drive/MyDrive/Human_Development_Index_Dataset.csv",encoding='latin1')
df.head()
# Out:
#    Unnamed: 0 iso3      country  year    hdi  life_expectancy  pop_millions  \
# 0           1  AFG  Afghanistan  1990  0.284           45.967     10.694796
# 1           2  AFG  Afghanistan  1991  0.292           46.663     10.745167
# 2           3  AFG  Afghanistan  1992  0.299           47.596     12.057433
# 3           4  AFG  Afghanistan  1993  0.307           51.466     14.003760
# 4           5  AFG  Afghanistan  1994  0.300           51.495     15.455554
#
#    hdi_f  hdi_m  life_expec_f  ...  gender_development  gender_inequality  \
# 0    NaN    NaN        48.397  ...                 NaN                NaN
# 1    NaN    NaN        49.144  ...                 NaN                NaN
# 2    NaN    NaN        50.320  ...                 NaN                NaN
# 3    NaN    NaN        52.739  ...                 NaN                NaN
# 4    NaN    NaN        53.544  ...                 NaN                NaN
#
#    secondary_education_f_%  secondary_education_m_%  seats_in_parliament_f_%  \
# 0                 1.107733                 7.899011                      NaN
# 1                 1.221396                 8.137953                      NaN
# 2                 1.335059                 8.376896                      NaN
# 3                 1.448722                 8.615838                      NaN
# 4                 1.562385                 8.854780                      NaN
#
#    seats_in_parliament_m_%  labour_participation_f_%  \
# 0                      NaN                       NaN
# 1                      NaN                       NaN
# 2                      NaN                       NaN
# 3                      NaN                       NaN
# 4                      NaN                       NaN
#
#    labour_participation_m_%  co2_emission_tons  mat_footprint_percap_tons
# 0                       NaN           0.189279                     2.1809
# 1                       NaN           0.178155                     2.5264
# 2                       NaN           0.122920                     2.6421
# 3                       NaN           0.106179                     2.3022
# 4                       NaN           0.094063                     1.8948
#
# [5 rows x 30 columns]

# %%
df.shape
# Out:
# (6798, 30)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'iso3', 'country', 'year', 'hdi', 'life_expectancy',
#        'pop_millions', 'hdi_f', 'hdi_m', 'life_expec_f', 'life_expec_m',
#        'expec_yr_school', 'expec_yr_school_f', 'expec_yr_school_m',
#        'mean_yr_school', 'mean_yr_school_f', 'mean_yr_school_m',
#        'gross_inc_percap', 'gross_inc_percap_f', 'gross_inc_percap_m',
#        'gender_development', 'gender_inequality', 'secondary_education_f_%',
#        'secondary_education_m_%', 'seats_in_parliament_f_%',
#        'seats_in_parliament_m_%', 'labour_participation_f_%',
#        'labour_participation_m_%', 'co2_emission_tons',
#        'mat_footprint_percap_tons'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6798 entries, 0 to 6797
# Data columns (total 30 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 6798 non-null   int64
#  1   iso3                       6798 non-null   object
#  2   country                    6798 non-null   object
#  3   year                       6798 non-null   int64
#  4   hdi                        6171 non-null   float64
#  5   life_expectancy            6798 non-null   float64
#  6   pop_millions               6798 non-null   float64
#  7   hdi_f                      5014 non-null   float64
#  8   hdi_m                      5014 non-null   float64
#  9   life_expec_f               6798 non-null   float64
#  10  life_expec_m               6798 non-null   float64
#  11  expec_yr_school            6550 non-null   float64
#  12  expec_yr_school_f          6270 non-null   float64
#  13  expec_yr_school_m          6270 non-null   float64
#  14  mean_yr_school             6254 non-null   float64
#  15  mean_yr_school_f           6164 non-null   float64
#  16  mean_yr_school_m           6164 non-null   float64
#  17  gross_inc_percap           6659 non-null   float64
#  18  gross_inc_percap_f         5292 non-null   float64
#  19  gross_inc_percap_m         5292 non-null   float64
#  20  gender_development         5014 non-null   float64
#  21  gender_inequality          4711 non-null   float64
#  22  secondary_education_f_%    5817 non-null   float64
#  23  secondary_education_m_%    5817 non-null   float64
#  24  seats_in_parliament_f_%    6269 non-null   float64
#  25  seats_in_parliament_m_%    6269 non-null   float64
#  26  labour_participation_f_%   5310 non-null   float64
#  27  labour_participation_m_%   5310 non-null   float64
#  28  co2_emission_tons          6713 non-null   float64
#  29  mat_footprint_percap_tons  5344 non-null   float64
# dtypes: float64(26), int64(2), object(2)
# memory usage: 1.6+ MB

# %%
#Problem - 1A - Single Year HDI Exploration (Latest Year: 2022)
#Task-1:
# Extracting Latest Year:
df['year'].unique()
hdi_2022_df = df[df['year'] == 2022].copy()

# %%
#Task-2:
#Data Exploration:
hdi_2022_df.head(10)
# Out:
#      Unnamed: 0 iso3              country  year    hdi  life_expectancy  \
# 32           33  AFG          Afghanistan  2022  0.462           62.879
# 65           66  ALB              Albania  2022  0.789           76.833
# 98           99  DZA              Algeria  2022  0.745           77.129
# 131         132  AND              Andorra  2022  0.884           83.552
# 164         165  AGO               Angola  2022  0.591           61.929
# 197         198  ATG  Antigua and Barbuda  2022  0.826           79.236
# 230         231  ARG            Argentina  2022  0.849           76.064
# 263         264  ARM              Armenia  2022  0.786           73.372
# 296         297  AUS            Australia  2022  0.946           83.579
# 329         330  AUT              Austria  2022  0.926           82.412
#
#      pop_millions     hdi_f     hdi_m  life_expec_f  ...  gender_development  \
# 32      41.128771  0.332443  0.534145        66.213  ...               0.622
# 65       2.842321  0.780277  0.798432        79.472  ...               0.977
# 98      44.903225  0.681844  0.773800        78.457  ...               0.881
# 131      0.079824       NaN       NaN        85.838  ...                 NaN
# 164     35.588987  0.560890  0.619680        64.541  ...               0.905
# 197      0.093763       NaN       NaN        81.645  ...                 NaN
# 230     45.510318  0.841405  0.845473        79.277  ...               0.995
# 263      2.780469  0.795110  0.774942        78.447  ...               1.026
# 296     26.177414  0.934602  0.955941        85.453  ...               0.978
# 329      8.939617  0.911592  0.937756        84.600  ...               0.972
#
#      gender_inequality  secondary_education_f_%  secondary_education_m_%  \
# 32               0.665                 7.042050                24.077040
# 65               0.116                82.249185                86.476634
# 98               0.460                42.910456                46.815170
# 131                NaN                81.718277                84.599998
# 164              0.520                21.339865                37.411946
# 197                NaN                      NaN                      NaN
# 230              0.292                73.591541                71.648085
# 263              0.198                96.001381                97.050957
# 296              0.063                94.580063                94.430069
# 329              0.048               100.000000               100.000000
#
#      seats_in_parliament_f_%  seats_in_parliament_m_%  \
# 32                 27.215190                72.784810
# 65                 35.714286                64.285714
# 98                  7.005254                92.994746
# 131                46.428571                53.571429
# 164                33.636364                66.363636
# 197                31.428571                68.571429
# 230                44.376900                55.623100
# 263                35.514019                64.485981
# 296                44.493392                55.506608
# 329                40.983607                59.016393
#
#      labour_participation_f_%  labour_participation_m_%  co2_emission_tons  \
# 32                      23.33                     77.09           0.306318
# 65                      56.08                     69.91           1.717758
# 98                      17.57                     65.53           4.079540
# 131                       NaN                       NaN           4.593593
# 164                     74.73                     78.16           0.507359
# 197                       NaN                       NaN           6.401056
# 230                     52.08                     71.74           4.190779
# 263                     62.80                     71.84           2.531088
# 296                     62.31                     71.13          14.914763
# 329                     56.55                     66.69           7.399461
#
#      mat_footprint_percap_tons
# 32                      1.1809
# 65                     11.7367
# 98                      8.7199
# 131                        NaN
# 164                     3.6568
# 197                        NaN
# 230                    14.4512
# 263                     7.3553
# 296                    26.9245
# 329                    27.9621
#
# [10 rows x 30 columns]

# %%
#number of rows and columns
hdi_2022_df.shape
# Out:
# (206, 30)

# %%
#all column names with their data types
hdi_2022_df.dtypes
# Out:
# Unnamed: 0                     int64
# iso3                          object
# country                       object
# year                           int64
# hdi                          float64
# life_expectancy              float64
# pop_millions                 float64
# hdi_f                        float64
# hdi_m                        float64
# life_expec_f                 float64
# life_expec_m                 float64
# expec_yr_school              float64
# expec_yr_school_f            float64
# expec_yr_school_m            float64
# mean_yr_school               float64
# mean_yr_school_f             float64
# mean_yr_school_m             float64
# gross_inc_percap             float64
# gross_inc_percap_f           float64
# gross_inc_percap_m           float64
# gender_development           float64
# gender_inequality            float64
# secondary_education_f_%      float64
# secondary_education_m_%      float64
# seats_in_parliament_f_%      float64
# seats_in_parliament_m_%      float64
# labour_participation_f_%     float64
# labour_participation_m_%     float64
# co2_emission_tons            float64
# mat_footprint_percap_tons    float64
# dtype: object

# %%
#Task-3
#Missing Values & Data Cleaning:
hdi_2022_df.isnull().sum()
# Out:
# Unnamed: 0                    0
# iso3                          0
# country                       0
# year                          0
# hdi                           2
# life_expectancy               0
# pop_millions                  0
# hdi_f                        13
# hdi_m                        13
# life_expec_f                  0
# life_expec_m                  0
# expec_yr_school               1
# expec_yr_school_f             1
# expec_yr_school_m             1
# mean_yr_school                2
# mean_yr_school_f              2
# mean_yr_school_m              2
# gross_inc_percap              2
# gross_inc_percap_f           13
# gross_inc_percap_m           13
# gender_development           13
# gender_inequality            29
# secondary_education_f_%      17
# secondary_education_m_%      17
# seats_in_parliament_f_%       2
# seats_in_parliament_m_%       2
# labour_participation_f_%     12
# labour_participation_m_%     12
# co2_emission_tons             2
# mat_footprint_percap_tons    41
# dtype: int64

# %%
hdi_2022_df['country'].nunique(), hdi_2022_df.shape[0]
# Out:
# (206, 206)

# %%
#handling the missing values
numeric_cols = hdi_2022_df.select_dtypes(include=["number"]).columns
df[numeric_cols] = hdi_2022_df[numeric_cols].fillna(df[numeric_cols].mean())
hdi_2022_df = hdi_2022_df.dropna(subset=['hdi'])

# %%
#removing duplicates(repeated rows from the dataset)
hdi_2022_df = hdi_2022_df.drop_duplicates()

# %%
#Converting Numeric Columns (handling “–” or text values)
numeric_cols = [
    'hdi',
    'life_expectancy',
    'gross_inc_percap',
    'gender_development'
]

for col in numeric_cols:
    hdi_2022_df[col] = pd.to_numeric(hdi_2022_df[col], errors='coerce')
hdi_2022_df = hdi_2022_df.dropna(subset=['hdi'])
hdi_2022_df
# Out:
#       Unnamed: 0       iso3                          country  year    hdi  \
# 32            33        AFG                      Afghanistan  2022  0.462
# 65            66        ALB                          Albania  2022  0.789
# 98            99        DZA                          Algeria  2022  0.745
# 131          132        AND                          Andorra  2022  0.884
# 164          165        AGO                           Angola  2022  0.591
# ...          ...        ...                              ...   ...    ...
# 6665        6666    ZZG.ECA          Europe and Central Asia  2022  0.802
# 6698        6699    ZZH.LAC  Latin America and the Caribbean  2022  0.763
# 6731        6732     ZZI.SA                       South Asia  2022  0.641
# 6764        6765    ZZJ.SSA               Sub-Saharan Africa  2022  0.549
# 6797        6798  ZZK.WORLD                            World  2022  0.739
#
#       life_expectancy  pop_millions     hdi_f     hdi_m  life_expec_f  ...  \
# 32          62.879000     41.128771  0.332443  0.534145     66.213000  ...
# 65          76.833000      2.842321  0.780277  0.798432     79.472000  ...
# 98          77.129000     44.903225  0.681844  0.773800     78.457000  ...
# 131         83.552000      0.079824       NaN       NaN     85.838000  ...
# 164         61.929000     35.588987  0.560890  0.619680     64.541000  ...
# ...               ...           ...       ...       ...           ...  ...
# 6665        73.564575    247.791584  0.785084  0.815007     77.021724  ...
# 6698        73.715085    655.268078  0.758014  0.765042     76.886510  ...
# 6731        68.441543   2007.549714  0.580274  0.678378     70.384339  ...
# 6764        60.639700   1146.742474  0.525081  0.573585     62.621953  ...
# 6797        72.004070   7940.608797  0.719488  0.756395     74.532307  ...
#
#       gender_development  gender_inequality  secondary_education_f_%  \
# 32                 0.622              0.665                 7.042050
# 65                 0.977              0.116                82.249185
# 98                 0.881              0.460                42.910456
# 131                  NaN                NaN                81.718277
# 164                0.905              0.520                21.339865
# ...                  ...                ...                      ...
# 6665               0.963              0.224                83.748828
# 6698               0.991              0.386                64.359830
# 6731               0.855              0.478                40.903060
# 6764               0.915              0.565                30.864417
# 6797               0.951              0.462                64.118558
#
#       secondary_education_m_%  seats_in_parliament_f_%  \
# 32                  24.077040                27.215190
# 65                  86.476634                35.714286
# 98                  46.815170                 7.005254
# 131                 84.599998                46.428571
# 164                 37.411946                33.636364
# ...                       ...                      ...
# 6665                89.899225                26.012512
# 6698                64.202583                34.100834
# 6731                55.677277                17.930080
# 6764                42.045967                26.360216
# 6797                70.967411                26.184549
#
#       seats_in_parliament_m_%  labour_participation_f_%  \
# 32                  72.784810                 23.330000
# 65                  64.285714                 56.080000
# 98                  92.994746                 17.570000
# 131                 53.571429                       NaN
# 164                 66.363636                 74.730000
# ...                       ...                       ...
# 6665                73.987488                 45.388503
# 6698                65.899166                 51.625204
# 6731                82.069920                 28.110055
# 6764                73.639784                 63.919192
# 6797                73.815451                 46.799926
#
#       labour_participation_m_%  co2_emission_tons  mat_footprint_percap_tons
# 32                   77.090000           0.306318                   1.180900
# 65                   69.910000           1.717758                  11.736700
# 98                   65.530000           4.079540                   8.719900
# 131                        NaN           4.593593                        NaN
# 164                  78.160000           0.507359                   3.656800
# ...                        ...                ...                        ...
# 6665                 69.591635           5.308463                  10.907875
# 6698                 75.301374           2.629329                  12.354312
# 6731                 76.307951           1.875161                   4.882850
# 6764                 76.428981           0.720271                   3.786977
# 6797                 73.880522           4.497895                  12.470560
#
# [204 rows x 30 columns]

# %%
#Task-4:
#Basic Statistics:
#Computing the mean, median, and standard deviation of HDI for the year 2022

hdi_mean = hdi_2022_df['hdi'].mean()
hdi_median = hdi_2022_df['hdi'].median()
hdi_std = hdi_2022_df['hdi'].std()

hdi_mean, hdi_median, hdi_std
# Out:
# (np.float64(0.7228872549019609), 0.7395, 0.15302880386427825)

# %%
#country with the highest HDI in 2022.
hdi_2022_df.loc[hdi_2022_df['hdi'].idxmax(), ['country', 'hdi']]
# Out:
# country    Switzerland
# hdi              0.967
# Name: 5609, dtype: object

# %%
#country with the lowest HDI in 2022.
hdi_2022_df.loc[hdi_2022_df['hdi'].idxmin(), ['country', 'hdi']]
# Out:
# country    Somalia
# hdi           0.38
# Name: 5345, dtype: object

# %%
#Task-5
#Filtering and Sorting:
#countries with HDI {"hdi"} greater than 0.800.
high_hdi_df = hdi_2022_df[hdi_2022_df['hdi'] > 0.800]
high_hdi_df_sorted = high_hdi_df.sort_values(
    by='gross_inc_percap',
    ascending=False
)

# %%
#Displaying the top 10 countries.
high_hdi_df_sorted.head(10)
# Out:
#       Unnamed: 0 iso3                 country  year    hdi  life_expectancy  \
# 3332        3333  LIE           Liechtenstein  2022  0.942           84.656
# 4718        4719  QAT                   Qatar  2022  0.875           81.559
# 5213        5214  SGP               Singapore  2022  0.949           84.133
# 2705        2706  IRL                 Ireland  2022  0.950           82.716
# 3398        3399  LUX              Luxembourg  2022  0.927           82.591
# 6104        6105  ARE    United Arab Emirates  2022  0.937           79.196
# 5609        5610  CHE             Switzerland  2022  0.967           84.255
# 4322        4323  NOR                  Norway  2022  0.966           83.393
# 6170        6171  USA           United States  2022  0.927           78.203
# 2474        2475  HKG  Hong Kong, China (SAR)  2022  0.956           84.315
#
#       pop_millions     hdi_f     hdi_m  life_expec_f  ...  gender_development  \
# 3332      0.039327  0.924163  0.974295        86.129  ...               0.949
# 4718      2.695122  0.892561  0.869100        83.101  ...               1.027
# 5213      5.975689  0.945325  0.954078        86.295  ...               0.991
# 2705      5.023109  0.942838  0.951392        84.412  ...               0.991
# 3398      0.647599  0.920482  0.927311        84.770  ...               0.993
# 6104      9.441128  0.922940  0.936027        81.412  ...               0.986
# 5609      8.740472  0.949369  0.977383        85.932  ...               0.971
# 4322      5.434319  0.957148  0.970415        85.055  ...               0.986
# 6170    338.289857  0.927693  0.923405        81.015  ...               1.005
# 2474      7.488865  0.942671  0.969515        86.893  ...               0.972
#
#       gender_inequality  secondary_education_f_%  secondary_education_m_%  \
# 3332                NaN                      NaN                      NaN
# 4718              0.212                81.832741                71.417976
# 5213              0.036                80.464020                85.932037
# 2705              0.072                88.585639                86.417415
# 3398              0.043                96.579350                89.328283
# 6104              0.035                82.029137                86.145172
# 5609              0.018                96.939726                97.517437
# 4322              0.012                99.094031                99.274980
# 6170              0.180                95.424278                95.067093
# 2474                NaN                77.866913                84.067802
#
#       seats_in_parliament_f_%  seats_in_parliament_m_%  \
# 3332                28.000000                72.000000
# 4718                 4.444444                95.555556
# 5213                29.126214                70.873786
# 2705                27.397260                72.602740
# 3398                33.333333                66.666667
# 6104                50.000000                50.000000
# 5609                39.024390                60.975610
# 4322                44.970414                55.029586
# 6170                28.060264                71.939736
# 2474                      NaN                      NaN
#
#       labour_participation_f_%  labour_participation_m_%  co2_emission_tons  \
# 3332                     52.79                     67.26           3.736776
# 4718                     61.73                     95.33          39.884274
# 5213                     63.37                     77.00           9.397481
# 2705                     59.40                     70.51           7.529751
# 3398                     57.99                     65.09          13.185395
# 6104                     55.32                     89.45          25.333276
# 5609                     61.49                     71.94           4.117550
# 4322                     62.53                     69.59           7.573541
# 6170                     56.79                     67.97          14.932487
# 2474                     52.91                     64.71           4.373242
#
#       mat_footprint_percap_tons
# 3332                        NaN
# 4718                    63.5912
# 5213                    43.1508
# 2705                    26.3467
# 3398                    49.1903
# 6104                    28.1632
# 5609                    33.5913
# 4322                    32.0515
# 6170                    29.3498
# 2474                        NaN
#
# [10 rows x 30 columns]

# %%
#Task-6
#Adding HDI Category Column:
def hdi_category(hdi):
    if hdi < 0.550:
        return "Low"
    elif hdi < 0.700:
        return "Medium"
    elif hdi < 0.800:
        return "High"
    else:
        return "Very High"

hdi_2022_df['HDI Category'] = hdi_2022_df['hdi'].apply(hdi_category)

# %%
hdi_2022_df['HDI Category'].value_counts()
# Out:
# HDI Category
# Very High    71
# High         54
# Medium       44
# Low          35
# Name: count, dtype: int64

# %%
hdi_2022_df.to_csv("HDI_category_added.csv", index=False)

# %%
#updated shape after adding HDI category
hdi_2022_df.shape
# Out:
# (204, 31)

# %%
#Problem - 1B - HDI Visualization and Trend Analysis (2020 – 2022)
#Task-1
#Data Extraction and Saving:
#Filtering the dataset to include only the years 2020, 2021, and 2022.
df = pd.read_csv("/content/drive/MyDrive/Human_Development_Index_Dataset.csv",encoding='latin1')
hdi_1b_df = df[df['year'].isin([2020, 2021, 2022])].copy()

# %%
hdi_1b_df.to_csv("HDI_problem1B.csv", index=False)

# %%
#Task-2
#Data Cleaning and Inspecting Missing Values:

hdi_1b_df[['hdi', 'country', 'year']].isnull().sum()
# Out:
# hdi        8
# country    0
# year       0
# dtype: int64

# %%
#country name consistency
hdi_1b_df['country'].nunique(), hdi_1b_df.shape[0]
# Out:
# (206, 618)

# %%
#duplicate rows(records)
hdi_1b_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#numeric columns stored as text or containing non-numeric symbols (e.g., “–”).
numeric_cols = [
    'hdi',
    'life_expectancy',
    'gross_inc_percap',
    'gender_development'
]

for col in numeric_cols:
    hdi_1b_df[col] = pd.to_numeric(hdi_1b_df[col], errors='coerce')

# %%
hdi_1b_df = hdi_1b_df.drop_duplicates()

# %%
#removes rows where the HDI, country, or year values are missing
hdi_1b_df = hdi_1b_df.dropna(subset=['hdi', 'country', 'year'])

# %%
#Task-3
#Visualization Tasks:
#Selecting any five countries
selected_countries = ['Nepal', 'Qatar', 'Switzerland', 'China', 'United States']

# %%
#HDI values for each country across the years 2020, 2021, and 2022.
country_trend_df = hdi_1b_df[hdi_1b_df['country'].isin(selected_countries)]
country_trend_df
# Out:
#       Unnamed: 0 iso3        country  year    hdi  life_expectancy  \
# 1185        1186  CHN          China  2020  0.781           78.077
# 1186        1187  CHN          China  2021  0.785           78.211
# 1187        1188  CHN          China  2022  0.788           78.587
# 4089        4090  NPL          Nepal  2020  0.593           69.246
# 4090        4091  NPL          Nepal  2021  0.591           68.450
# 4091        4092  NPL          Nepal  2022  0.601           70.484
# 4716        4717  QAT          Qatar  2020  0.863           79.099
# 4717        4718  QAT          Qatar  2021  0.864           79.272
# 4718        4719  QAT          Qatar  2022  0.875           81.559
# 5607        5608  CHE    Switzerland  2020  0.957           83.067
# 5608        5609  CHE    Switzerland  2021  0.965           83.987
# 5609        5610  CHE    Switzerland  2022  0.967           84.255
# 6168        6169  USA  United States  2020  0.923           77.414
# 6169        6170  USA  United States  2021  0.921           77.198
# 6170        6171  USA  United States  2022  0.927           78.203
#
#       pop_millions     hdi_f     hdi_m  life_expec_f  ...  gender_development  \
# 1185   1424.929781  0.764239  0.793824        81.058  ...               0.963
# 1186   1425.893465  0.768986  0.798418        81.155  ...               0.963
# 1187   1425.887337  0.771343  0.802194        81.343  ...               0.962
# 4089     29.348627  0.554200  0.627231        71.173  ...               0.884
# 4090     30.034989  0.552369  0.624692        70.362  ...               0.884
# 4091     30.547580  0.562283  0.635119        72.364  ...               0.885
# 4716      2.760385  0.873809  0.857939        80.679  ...               1.018
# 4717      2.688235  0.875835  0.858358        80.937  ...               1.020
# 4718      2.695122  0.892561  0.869100        83.101  ...               1.027
# 5607      8.638613  0.940662  0.969007        85.078  ...               0.971
# 5608      8.691406  0.948632  0.974925        85.896  ...               0.973
# 5609      8.740472  0.949369  0.977383        85.932  ...               0.971
# 6168    335.942003  0.921612  0.922559        80.308  ...               0.999
# 6169    336.997624  0.922756  0.917103        80.238  ...               1.006
# 6170    338.289857  0.927693  0.923405        81.015  ...               1.005
#
#       gender_inequality  secondary_education_f_%  secondary_education_m_%  \
# 1185              0.190                79.701982                86.365801
# 1186              0.185                79.701982                86.365801
# 1187              0.186                79.701982                86.365801
# 4089              0.497                25.972874                42.779256
# 4090              0.496                25.972874                42.779256
# 4091              0.495                25.972874                42.779256
# 4716              0.168                81.832741                71.417976
# 4717              0.216                81.832741                71.417976
# 4718              0.212                81.832741                71.417976
# 5607              0.018                96.939726                97.517437
# 5608              0.017                96.939726                97.517437
# 5609              0.018                96.939726                97.517437
# 6168              0.186                96.548347                96.366661
# 6169              0.187                95.424278                95.067093
# 6170              0.180                95.424278                95.067093
#
#       seats_in_parliament_f_%  seats_in_parliament_m_%  \
# 1185                24.941176                75.058824
# 1186                24.941176                75.058824
# 1187                24.941176                75.058824
# 4089                33.633634                66.366366
# 4090                33.633634                66.366366
# 4091                33.832335                66.167665
# 4716                 9.756098                90.243902
# 4717                 4.444444                95.555556
# 4718                 4.444444                95.555556
# 5607                38.617886                61.382114
# 5608                39.837398                60.162602
# 5609                39.024390                60.975610
# 6168                27.099237                72.900763
# 6169                26.966292                73.033708
# 6170                28.060264                71.939736
#
#       labour_participation_f_%  labour_participation_m_%  co2_emission_tons  \
# 1185                     53.17                     74.04           7.659333
# 1186                     53.76                     74.54           7.950279
# 1187                     53.76                     74.54           7.950279
# 4089                     27.91                     54.95           0.507772
# 4090                     27.91                     54.95           0.520340
# 4091                     27.91                     54.95           0.520340
# 4716                     58.40                     95.75          37.132936
# 4717                     59.60                     95.41          39.884274
# 4718                     61.73                     95.33          39.884274
# 5607                     62.51                     73.39           3.963044
# 5608                     62.23                     72.68           4.117550
# 5609                     61.49                     71.94           4.117550
# 6168                     56.20                     67.66          14.034053
# 6169                     56.09                     67.60          14.932487
# 6170                     56.79                     67.97          14.932487
#
#       mat_footprint_percap_tons
# 1185                    23.0891
# 1186                    23.9471
# 1187                    24.2832
# 4089                     8.0381
# 4090                     8.3894
# 4091                     8.4528
# 4716                    59.4577
# 4717                    60.4693
# 4718                    63.5912
# 5607                    34.9022
# 5608                    34.8143
# 5609                    33.5913
# 6168                    27.8353
# 6169                    29.3477
# 6170                    29.3498
#
# [15 rows x 30 columns]

# %%
plt.figure(figsize=(8,6))
sns.lineplot(
    data=country_trend_df,
    x='year',
    y='hdi',
    hue='country',
    marker='o'
)
plt.title("HDI Trends (2020–2022) for Selected Countries")
plt.xlabel("Year")
plt.ylabel("HDI")
plt.legend(title="Country")
plt.savefig("hdi_trends.png")
plt.show()

# %%
#Generate Visualizations:
#Bar Chart: Average HDI by Region (2020–2022)
#Group the dataset by Region and Year.
'Region' in hdi_1b_df.columns
# The dataset does not contain a Region column.
# Out:
# False

# %%
# Creating region lists manually
south_asia = [
    "Afghanistan", "Bangladesh", "Bhutan", "India",
    "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

middle_east = [
    "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
    "Kuwait", "Lebanon", "Oman", "Palestine",
    "Qatar", "Saudi Arabia", "Syria",
    "United Arab Emirates", "Yemen"
]

europe = [
    "Austria", "Belgium", "Denmark", "Finland", "France",
    "Germany", "Italy", "Netherlands", "Norway",
    "Spain", "Sweden", "Switzerland", "United Kingdom"
]

east_asia = [
    "China", "Japan", "South Korea", "Mongolia"
]

africa = [
    "Nigeria", "Kenya", "Ethiopia", "Ghana",
    "South Africa", "Uganda", "Tanzania"
]

# Function to assign region based on country name
def assign_region(country):
    if country in south_asia:
        return "South Asia"      # South Asian countries
    elif country in middle_east:
        return "Middle East"     # Middle Eastern countries
    elif country in europe:
        return "Europe"          # European countries
    elif country in east_asia:
        return "East Asia"       # East Asian countries
    elif country in africa:
        return "Africa"          # African countries
    else:
        return "Other"           # Not in listed regions

# Apply the function to create a new Region column
hdi_1b_df["Region"] = hdi_1b_df["country"].apply(assign_region)

# %%
# Group by Region and Year
avg_hdi = (
    hdi_1b_df
    .groupby(["Region", "year"])["hdi"]
    .mean()
    .reset_index()
)

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

# Unique years and regions
years = sorted(avg_hdi["year"].unique())
regions = avg_hdi["Region"].unique()

# Bar settings
x = np.arange(len(years))
width = 0.15

region_colors = {
    "South Asia": "green",
    "Middle East": "lightgreen",
    "Africa": "blue",
    "East Asia": "orange",
    "Europe": "red"
}

# Plot grouped bars
for i, region in enumerate(regions):
    region_data = avg_hdi[avg_hdi["Region"] == region]
    plt.bar(
        x + i * width,
        region_data["hdi"],
        width,
        label=region,
        color=region_colors.get(region, "gray")
    )

# Axis labels and title
plt.xlabel("Year")
plt.ylabel("Average HDI")
plt.title("Average HDI by Region (2020–2022)")

# X-axis ticks
plt.xticks(x + width * (len(regions) / 2), years)

# Legend
plt.legend(title="Region", bbox_to_anchor=(1.05, 1), loc="upper left")

plt.tight_layout()
plt.savefig("avg_hdi_by_region.png")
plt.show()

# %%
#Box Plot: HDI Distribution for 2020, 2021, and 2022
plt.figure(figsize=(7,5))
sns.boxplot(
    data=hdi_1b_df,
    x='year',
    y='hdi',
    color="green"
)
plt.title("HDI Distribution (2020–2022)")
plt.xlabel("Year")
plt.ylabel("HDI")
plt.savefig("hdi_distribution.png")
plt.show()

# %%
#Calculates yearly summary statistics (mean, min, max, quartiles) of HDI values.
hdi_1b_df.groupby('year')['hdi'].describe()
# Out:
#       count      mean       std    min     25%     50%     75%    max
# year
# 2020  203.0  0.720897  0.148244  0.386  0.6135  0.7370  0.8300  0.963
# 2021  203.0  0.720039  0.150150  0.381  0.6045  0.7370  0.8340  0.965
# 2022  204.0  0.722887  0.153029  0.380  0.6065  0.7395  0.8395  0.967

# %%
# Checking if GNI per Capita column exists or not
if "gross_inc_percap" in hdi_1b_df:

    x = hdi_1b_df["gross_inc_percap"]
    y = hdi_1b_df["hdi"]

    plt.figure(figsize=(7,7))

    # Scatter plot (HDI vs GNI)
    plt.scatter(x, y, color='green', alpha=0.6, label='HDI vs GNI per Capita')

    plt.xlabel("GNI per Capita")
    plt.ylabel("HDI")
    plt.title("HDI vs GNI per Capita")
    plt.legend()
    plt.savefig("hdi_vs_gni.png")
    plt.show()


else:
    print("GNI per Capita variable not available in the dataset.")

# %%
#Computes HDI change from 2020 to 2022 for each country and lists the top increases.
hdi_change = (
    hdi_1b_df.pivot(index='country', columns='year', values='hdi')
)

hdi_change['HDI Change'] = hdi_change[2022] - hdi_change[2020]
hdi_change.sort_values('HDI Change', ascending=False).head()
# Out:
# year         2020   2021   2022  HDI Change
# country
# Andorra     0.843  0.855  0.884       0.041
# Azerbaijan  0.722  0.738  0.760       0.038
# Ecuador     0.734  0.746  0.765       0.031
# Maldives    0.737  0.753  0.762       0.025
# Mexico      0.757  0.757  0.781       0.024

# %%
#top five rows
hdi_change.sort_values('HDI Change').head()
# Out:
# year          2020   2021   2022  HDI Change
# country
# Timor-Leste  0.633  0.574  0.566      -0.067
# Ukraine      0.762  0.755  0.734      -0.028
# Afghanistan  0.488  0.473  0.462      -0.026
# Namibia      0.634  0.616  0.610      -0.024
# Lebanon      0.742  0.725  0.723      -0.019

# %%
#Problem-2 Advanced HDI Exploration:
#Task-1
#Creating South Asia Subset:
df=pd.read_csv("/content/drive/MyDrive/Human_Development_Index_Dataset.csv",encoding='latin')
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India",
    "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

# %%
south_asia_df = df[df['country'].isin(south_asian_countries)].copy()

# %%
#Saving the filtered dataset as HDI SouthAsia.csv
south_asia_df.to_csv("HDI_SouthAsia.csv", index=False)

# %%
#Task-2
# Composite Development Score:
south_asia_df['life_expectancy'] = pd.to_numeric(
    south_asia_df['life_expectancy'], errors='coerce'
)

south_asia_df['gross_inc_percap'] = pd.to_numeric(
    south_asia_df['gross_inc_percap'], errors='coerce'
)

#USING FORMULAE
south_asia_df['Composite Score'] = (
    0.30 * south_asia_df['life_expectancy'] +
    0.30 * south_asia_df['gross_inc_percap']
)

# %%
#Ranking South Asian countries based on Composite Score.
avg_composite = (
    south_asia_df
    .groupby("country", as_index=False)["Composite Score"]
    .mean()
)
top5_avg = avg_composite.sort_values(
    "Composite Score", ascending=False
).head(5)
top5_avg
# Out:
#      country  Composite Score
# 4   Maldives      4154.252676
# 7  Sri Lanka      2502.612949
# 2     Bhutan      1878.321569
# 6   Pakistan      1184.282350
# 3      India      1151.101140

# %%
#for comparing HDI and Composite_Score
south_asia_hdi = (
    south_asia_df
    .groupby("country", as_index=False)["hdi"]
    .mean()
    .sort_values("hdi", ascending=False)
)

south_asia_hdi
# Out:
#        country       hdi
# 7    Sri Lanka  0.715606
# 4     Maldives  0.682500
# 2       Bhutan  0.634538
# 3        India  0.541485
# 1   Bangladesh  0.531303
# 5        Nepal  0.504242
# 6     Pakistan  0.472545
# 0  Afghanistan  0.401030

# %%
#top 5 countries in a horizontal bar chart.
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.barh(top5_avg["country"], top5_avg["Composite Score"])
plt.xlabel("Average Composite Score")
plt.ylabel("Country")
plt.title("Top 5 South Asian Countries by Average Composite Score")
plt.gca().invert_yaxis()
plt.savefig("top5_composite.png")
plt.show()

# %%
#Task-3
#Detecting outliers in HDI and GNI per Capita using the 1.5 × IQR rule.
def detect_outliers(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return (series < lower) | (series > upper)

# Create a copy of the South Asia dataframe
outlier_df = south_asia_df.copy()

# Detect outliers
outlier_df['HDI Outlier'] = detect_outliers(outlier_df['hdi'])
outlier_df['GNI Outlier'] = detect_outliers(outlier_df['gross_inc_percap'])

# %%
#scatter plot of GNI per Capita vs HDI
plt.figure(figsize=(7,6))

plt.scatter(
  outlier_df['gross_inc_percap'],
  outlier_df['hdi'],
  label='Normal',
  alpha=0.7
)

outliers = outlier_df[outlier_df['HDI Outlier'] | outlier_df['GNI Outlier']]

plt.scatter(
    outliers['gross_inc_percap'],
    outliers['hdi'],
    label='Outliers',
    edgecolors='green',
    facecolors='none',
    s=100
)

plt.xlabel("GNI_per_Capita")
plt.ylabel("HDI")
plt.title("Outliers in South Asia: HDI vs GNI (2022)")
plt.legend()
plt.savefig("outliers_hdi_gni.png")
plt.show()

# %%
#Task-3
#Select two HDI components
south_asia_df['gender_development'] = pd.to_numeric(
    south_asia_df['gender_development'], errors='coerce'
)
south_asia_df['life_expectancy'] = pd.to_numeric(
    south_asia_df['life_expectancy'], errors='coerce'
)

# Pearson correlation

corr_gdi = south_asia_df['hdi'].corr(south_asia_df['gender_development'])
corr_lei = south_asia_df['hdi'].corr(south_asia_df['life_expectancy'])

print(corr_gdi, corr_lei)
# Out:
# 0.8656210050127539 0.9587610559043978

# %%
# Scatter plot: HDI vs Gender Development Index
plt.figure(figsize=(6,4))
sns.regplot(
    x='gender_development',
    y='hdi',
    data=south_asia_df,
    scatter_kws={'alpha':0.6}
)
plt.title('HDI vs Gender Development Index')
plt.xlabel('Gender Development Index')
plt.ylabel('HDI')
plt.savefig("hdi_vs_gdi.png")
plt.show()

# Scatter plot: HDI vs Life Expectancy
plt.figure(figsize=(6,4))
sns.regplot(
    x='life_expectancy',
    y='hdi',
    data=south_asia_df,
    scatter_kws={'alpha':0.6}
)
plt.title('HDI vs Life Expectancy')
plt.xlabel('Life Expectancy')
plt.ylabel('HDI')
plt.savefig("hdi_vs_life_exp.png")
plt.show()

# %%
# Creating GNI–HDI Gap
south_asia_df['GNI_HDI_Gap'] = south_asia_df['gross_inc_percap'] - south_asia_df['hdi']
countrywise_avg_gap = (
    south_asia_df
    .groupby('country', as_index=False)['GNI_HDI_Gap']
    .mean()
)

# %%
#Ranking South Asian countries by GNI HDI Gap in descending order
gap_desc = countrywise_avg_gap.sort_values(
    by='GNI_HDI_Gap', ascending=False
)
gap_desc
# Out:
#        country   GNI_HDI_Gap
# 4     Maldives  14670.635594
# 2       Bhutan   9320.175767
# 7    Sri Lanka   8268.373527
# 6     Pakistan   3883.813530
# 3        India   3771.381346
# 1   Bangladesh   3408.490410
# 5        Nepal   2532.443971
# 0  Afghanistan   1793.487770

# %%
#Ranking South Asian countries by GNI HDI Gap in ascending order
gap_asc = countrywise_avg_gap.sort_values(
    by='GNI_HDI_Gap', ascending=True
)
gap_asc
# Out:
#        country   GNI_HDI_Gap
# 0  Afghanistan   1793.487770
# 5        Nepal   2532.443971
# 1   Bangladesh   3408.490410
# 3        India   3771.381346
# 6     Pakistan   3883.813530
# 7    Sri Lanka   8268.373527
# 2       Bhutan   9320.175767
# 4     Maldives  14670.635594

# %%
# Top 3 positive gaps (high GNI relative to HDI)
top3_positive = gap_desc.head(3)

# Top 3 negative gaps (low GNI but relatively higher HDI)
top3_negative = gap_asc.head(3)

# %%
#Plot
plt.figure()
plt.bar(top3_positive['country'], top3_positive['GNI_HDI_Gap'],color="green")
plt.title('Top 3 Positive GNI–HDI Gaps')
plt.xlabel('Country')
plt.ylabel('Average GNI–HDI Gap')
plt.savefig("top3_gap_positive.png")
plt.show()

plt.figure()
plt.bar(top3_negative['country'], top3_negative['GNI_HDI_Gap'],color="green")
plt.title('Top 3 Negative GNI–HDI Gaps')
plt.xlabel('Country')
plt.ylabel('Average GNI–HDI Gap')
plt.savefig("top3_gap_negative.png")
plt.show()

# %%
#Problem-3
#Task-1
#Comparative Regional Analysis: South Asia vs Middle East
#dataset from Problem 1B
df = pd.read_csv("HDI_problem1B.csv")

# Creating Middle East Subset:
middle_east_countries = [
    "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
    "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar",
    "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"
]
south_asia_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India",
    "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]

south_asia_df = df[df['country'].isin(south_asia_countries)].copy()
middle_east_df = df[df['country'].isin(middle_east_countries)].copy()

# %%
#Saving these subsets
south_asia_df.to_csv("HDI_SouthAsia_2020_2022.csv", index=False)
middle_east_df.to_csv("HDI_MiddleEast_2020_2022.csv", index=False)

# %%
#Task-2 Descriptive Statistics:

#mean and standard deviation
south_asia_mean = south_asia_df['hdi'].mean()
south_asia_std = south_asia_df['hdi'].std()

middle_east_mean = middle_east_df['hdi'].mean()
middle_east_std = middle_east_df['hdi'].std()

print("South Asia HDI Statistics (2020–2022)")
print("Mean HDI:", round(south_asia_mean, 3))
print("Standard Deviation:", round(south_asia_std, 3))

print("\nMiddle East HDI Statistics (2020–2022)")
print("Mean HDI:", round(middle_east_mean, 3))
print("Standard Deviation:", round(middle_east_std, 3))
# Out:
# South Asia HDI Statistics (2020–2022)
# Mean HDI: 0.64
# Standard Deviation: 0.098
#
# Middle East HDI Statistics (2020–2022)
# Mean HDI: 0.789
# Standard Deviation: 0.141

# %%
#Task 3
#Top and Bottom Performers:
# Average HDI per country (2020–2022)
sa_avg = south_asia_df.groupby('country')['hdi'].mean().sort_values(ascending=False)
me_avg = middle_east_df.groupby('country')['hdi'].mean().sort_values(ascending=False)

# %%
# Top and bottom performers
sa_top3 = sa_avg.head(3)
sa_bottom3 = sa_avg.tail(3)

print("South Asia – Top 3:\n", sa_top3)
print("\nSouth Asia – Bottom 3:\n", sa_bottom3)
# Out:
# South Asia – Top 3:
#  country
# Sri Lanka    0.780000
# Maldives     0.750667
# Bhutan       0.677667
# Name: hdi, dtype: float64
#
# South Asia – Bottom 3:
#  country
# Nepal          0.595000
# Pakistan       0.537667
# Afghanistan    0.474333
# Name: hdi, dtype: float64

# %%
me_top3 = me_avg.head(3)
me_bottom3 = me_avg.tail(3)
print("\nMiddle East – Top 3:\n", me_top3)
print("\nMiddle East – Bottom 3:\n", me_bottom3)
# Out:
# Middle East – Top 3:
#  country
# United Arab Emirates    0.932667
# Israel                  0.910667
# Bahrain                 0.885333
# Name: hdi, dtype: float64
#
# Middle East – Bottom 3:
#  country
# Lebanon    0.730000
# Iraq       0.667000
# Yemen      0.426333
# Name: hdi, dtype: float64

# %%
# Combining all top and bottom performers
combined = pd.concat([
    sa_top3, sa_bottom3,
    me_top3, me_bottom3
])

plt.figure()
combined.plot(kind='bar',color="green")
plt.title("Top and Bottom 3 HDI Performers (2020–2022)")
plt.ylabel("Average HDI")
plt.xlabel("Country")
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.savefig("top_bottom_performers.png")
plt.show()

# %%
#Task 4
#Metric Comparisons:
# Convert metrics to numeric
metric_cols = [
    "gender_development",
    "life_expectancy",
    "gross_inc_percap"
]

# %%
for col in metric_cols:
    south_asia_df.loc[:, col] = pd.to_numeric(
        south_asia_df[col], errors="coerce"
    )
    middle_east_df.loc[:, col] = pd.to_numeric(
        middle_east_df[col], errors="coerce"
    )

# %%
#Task 4
# Compute regional means (2020–2022)
sa_means = south_asia_df[metric_cols].mean()
me_means = middle_east_df[metric_cols].mean()

# %%
#Task 4
# gender_development
plt.figure()
pd.DataFrame({
    "South Asia": [sa_means["gender_development"]],
    "Middle East": [me_means["gender_development"]]
}).plot(
    kind="bar",
    color=["green", "lightgreen"]
)

plt.title("Gender Development Index: South Asia vs Middle East (2020–2022)")
plt.ylabel("Index Value")
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig("gender_development.png")
plt.show()

# %%
#Task 4
# life_expectancy
plt.figure()
pd.DataFrame({
    "South Asia": [sa_means["life_expectancy"]],
    "Middle East": [me_means["life_expectancy"]]
}).plot(
    kind="bar",
    color=["green", "lightgreen"]
)

plt.title("Life Expectancy Index: South Asia vs Middle East (2020–2022)")
plt.ylabel("Index Value")
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig("life_expectancy.png")
plt.show()

# %%
#Task 4
# gross_inc_percap
plt.figure()
pd.DataFrame({
    "South Asia": [sa_means["gross_inc_percap"]],
    "Middle East": [me_means["gross_inc_percap"]]
}).plot(
    kind="bar",
    color=["green", "lightgreen"]  # ← green & light green
)

plt.title("GNI per Capita Index: South Asia vs Middle East (2020–2022)")
plt.ylabel("Index Value")
plt.xticks(rotation=0)
plt.tight_layout()
plt.savefig("gni_percap.png")
plt.show()

# %%
#Task 5
#HDI Disparity:
#range (max – min) of HDI for each region.
sa_range = south_asia_df['hdi'].max() - south_asia_df['hdi'].min()
me_range = middle_east_df['hdi'].max() - middle_east_df['hdi'].min()

#coefficient of variation (CV = std/mean) for HDI.
sa_cv = south_asia_df['hdi'].std() / south_asia_df['hdi'].mean()
me_cv = middle_east_df['hdi'].std() / middle_east_df['hdi'].mean()

# %%
print("South Asia HDI Range:", round(sa_range, 3))
print("South Asia HDI CV:", round(sa_cv, 3))

print("\nMiddle East HDI Range:", round(me_range, 3))
print("Middle East HDI CV:", round(me_cv, 3))
# Out:
# South Asia HDI Range: 0.321
# South Asia HDI CV: 0.154
#
# Middle East HDI Range: 0.513
# Middle East HDI CV: 0.179

# %%
#Task 6
 #Correlation Analysis

# South Asia correlations
sa_corr_gdi = south_asia_df['hdi'].corr(south_asia_df['gender_development'])
sa_corr_life = south_asia_df['hdi'].corr(south_asia_df['life_expectancy'])

# Middle East correlations
me_corr_gdi = middle_east_df['hdi'].corr(middle_east_df['gender_development'])
me_corr_life = middle_east_df['hdi'].corr(middle_east_df['life_expectancy'])

print("South Asia:")
print("HDI vs Gender Development:", round(sa_corr_gdi, 3))
print("HDI vs Life Expectancy:", round(sa_corr_life, 3))

print("\nMiddle East:")
print("HDI vs Gender Development:", round(me_corr_gdi, 3))
print("HDI vs Life Expectancy:", round(me_corr_life, 3))
# Out:
# South Asia:
# HDI vs Gender Development: 0.874
# HDI vs Life Expectancy: 0.939
#
# Middle East:
# HDI vs Gender Development: 0.936
# HDI vs Life Expectancy: 0.933

# %%
#Task 6
# South Asia: HDI vs Gender Development
x = south_asia_df['gender_development']
y = south_asia_df['hdi']

plt.figure()
plt.scatter(x, y, color='green')
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='green')

plt.xlabel("Gender Development Index")
plt.ylabel("HDI")
plt.title("South Asia: HDI vs Gender Development Index")
plt.savefig("hdi_vs_gdi_dev.png")
plt.show()


# South Asia: HDI vs Life Expectancy
x = south_asia_df['life_expectancy']
y = south_asia_df['hdi']

plt.figure()
plt.scatter(x, y, color='green')
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='green')

plt.xlabel("Life Expectancy Index")
plt.ylabel("HDI")
plt.title("South Asia: HDI vs Life Expectancy Index")
plt.savefig("hdi_vs_gdi_life_expectancy.png")
plt.show()

# %%
#Task 6
# Middle East: HDI vs Gender Development
x = middle_east_df['gender_development']
y = middle_east_df['hdi']

plt.figure()
plt.scatter(x, y, color='green')
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='green')

plt.xlabel("Gender Development Index")
plt.ylabel("HDI")
plt.title("Middle East: HDI vs Gender Development Index")
plt.savefig("hdi_vs_gdi_dev(2).png")
plt.show()


# Middle East: HDI vs Life Expectancy
x = middle_east_df['life_expectancy']
y = middle_east_df['hdi']

plt.figure()
plt.scatter(x, y, color='green')
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='green')

plt.xlabel("Life Expectancy Index")
plt.ylabel("HDI")
plt.title("Middle East: HDI vs Life Expectancy Index")
plt.savefig("hdi_vs_life_expectancy(2).png")
plt.show()

# %%
#Task 7
#Outlier Detection:
def detect_outliers(series):
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return (series < lower) | (series > upper)

# %%
#Task 7
# South Asia outliers
# South Asia outliers
south_asia_df.loc[:, 'hdi_outlier'] = detect_outliers(south_asia_df['hdi'])
south_asia_df.loc[:, 'gni_outlier'] = detect_outliers(south_asia_df['gross_inc_percap'])

# Middle East outliers
middle_east_df.loc[:, 'hdi_outlier'] = detect_outliers(middle_east_df['hdi'])
middle_east_df.loc[:, 'gni_outlier'] = detect_outliers(middle_east_df['gross_inc_percap'])

# %%
#Task 7
plt.figure()
plt.scatter(
    south_asia_df['gross_inc_percap'],
    south_asia_df['hdi']
)
plt.scatter(
    south_asia_df.loc[south_asia_df['hdi_outlier'] | south_asia_df['gni_outlier'], 'gross_inc_percap'],
    south_asia_df.loc[south_asia_df['hdi_outlier'] | south_asia_df['gni_outlier'], 'hdi']
)

plt.title("South Asia: HDI vs GNI per Capita (Outliers Highlighted)")
plt.xlabel("GNI per Capita Index")
plt.ylabel("HDI")
plt.tight_layout()
plt.savefig("outliers_hdi_gni_sa.png")
plt.show()

# %%
#Task 7
plt.figure()
plt.scatter(
    middle_east_df['gross_inc_percap'],
    middle_east_df['hdi']
)
plt.scatter(
    middle_east_df.loc[middle_east_df['hdi_outlier'] | middle_east_df['gni_outlier'], 'gross_inc_percap'],
    middle_east_df.loc[middle_east_df['hdi_outlier'] | middle_east_df['gni_outlier'], 'hdi']
)

plt.title("Middle East: HDI vs GNI per Capita (Outliers Highlighted)")
plt.xlabel("GNI per Capita Index")
plt.ylabel("HDI")
plt.tight_layout()
plt.savefig("outliers_hdi_gni_me.png")
plt.show()
